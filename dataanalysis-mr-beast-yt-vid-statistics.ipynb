# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('/kaggle/input/mrbeast-youtubevideostatistics/mr_beast_youtube_stats.csv')

# %% [markdown]
# **Inspecting Data**

# %%
df.head()
# Out:
#             id                                              title  \
# 0  TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 1  ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# 2  cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# 3  GLoeAJUcz38                 Press This Button To Win $100,000!
# 4  nM89Wl03Q4g   I Survived 50 Hours In A Maximum Security Prison
#
#                                          description  \
# 0  Sign up for Current w/ my Creator Code "BEAST"...
# 1  I cant believe I spent over $500000 on mystery...
# 2  I didnt think he would actually rob the bank.....
# 3  Push the red subscribe button and you could al...
# 4  I can't believe this prison let me do this lol...
#
#                  publishedAt                publishTime     kind_stats  \
# 0  2021-04-24 20:00:00+00:00  2021-04-24 20:00:00+00:00  youtube#video
# 1  2021-04-03 20:00:01+00:00  2021-04-03 20:00:01+00:00  youtube#video
# ...

# %%
df.dtypes
# Out:
# id                            object
# title                         object
# description                   object
# publishedAt                   object
# publishTime                   object
# kind_stats                    object
# viewCount                      int64
# likeCount                    float64
# favoriteCount                  int64
# commentCount                 float64
# thumbnails.default.url        object
# thumbnails.default.width       int64
# thumbnails.default.height      int64
# thumbnails.medium.url         object
# thumbnails.medium.width        int64
# thumbnails.medium.height       int64
# thumbnails.high.url           object
# thumbnails.high.width          int64
# thumbnails.high.height         int64
# dtype: object

# %%
df.describe()
# Out:
#           viewCount     likeCount  favoriteCount   commentCount  \
# count  2.500000e+02  2.490000e+02          250.0     249.000000
# mean   5.098044e+07  1.582455e+06            0.0   74145.413655
# std    3.852701e+07  1.720624e+06            0.0   77193.992086
# min    1.386600e+04  3.670000e+02            0.0      59.000000
# 25%    1.673930e+07  4.856960e+05            0.0   26100.000000
# 50%    4.901873e+07  1.362989e+06            0.0   63343.000000
# 75%    7.959489e+07  2.231276e+06            0.0   96741.000000
# max    1.749843e+08  1.903690e+07            0.0  726784.000000
#
#        thumbnails.default.width  thumbnails.default.height  \
# count                     250.0                      250.0
# mean                      120.0                       90.0
# std                         0.0                        0.0
# min                       120.0                       90.0
# 25%                       120.0                       90.0
# ...

# %% [markdown]
# **> COLUMNS & ROWS**

# %%
df['viewCount']
# Out:
# 0       84559207
# 1      101439191
# 2       49468692
# 3      145013747
# 4       78945852
#          ...
# 245     82554253
# 246        40795
# 247        18716
# 248        16558
# 249     26230327
# Name: viewCount, Length: 250, dtype: int64

# %%
df.loc[5]
# Out:
# id                                                                 x9TQ6culXIA
# title                                        $1,000,000 Influencer Tournament!
# description                  That was so close at the end I can't believe t...
# publishedAt                                          2021-12-16 21:00:00+00:00
# publishTime                                          2021-12-16 21:00:00+00:00
# kind_stats                                                       youtube#video
# viewCount                                                             30929257
# likeCount                                                            2169506.0
# favoriteCount                                                                0
# commentCount                                                           78212.0
# thumbnails.default.url          https://i.ytimg.com/vi/x9TQ6culXIA/default.jpg
# thumbnails.default.width                                                   120
# ...

# %%
df = df.set_index('id')

# %%
df
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# GLoeAJUcz38                 Press This Button To Win $100,000!
# nM89Wl03Q4g   I Survived 50 Hours In A Maximum Security Prison
# ...                                                        ...
# RCvnytndd9c                      Last To Leave VR Wins $20,000
# pV7UcYW1OwA                Computer vs Console My Perspective.
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
# 56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# 3iaDrpKdaIc                   I Ubered Random People In A Tank
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# ayXxwJJId_c  I cant believe I spent over $500000 on mystery...
# ...

# %% [markdown]
# ****SUBSETTING DATA****

# %%
 df = df[['title','description',  'publishTime',
       'viewCount', 'likeCount', 'commentCount']]

# %%
df
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# GLoeAJUcz38                 Press This Button To Win $100,000!
# nM89Wl03Q4g   I Survived 50 Hours In A Maximum Security Prison
# ...                                                        ...
# RCvnytndd9c                      Last To Leave VR Wins $20,000
# pV7UcYW1OwA                Computer vs Console My Perspective.
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
# 56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# 3iaDrpKdaIc                   I Ubered Random People In A Tank
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# ayXxwJJId_c  I cant believe I spent over $500000 on mystery...
# ...

# %%
df.shape
# Out:
# (250, 6)

# %%
df.loc[df['viewCount'] > 1_000_000]
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# GLoeAJUcz38                 Press This Button To Win $100,000!
# nM89Wl03Q4g   I Survived 50 Hours In A Maximum Security Prison
# ...                                                        ...
# 2IGxSOfsBok                              I Hate Pewdiepie!!!!!
# bEIK5ni_Pzs   How Many People Get The Diamond Play Button?????
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# RCvnytndd9c                      Last To Leave VR Wins $20,000
# 3iaDrpKdaIc                   I Ubered Random People In A Tank
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# ayXxwJJId_c  I cant believe I spent over $500000 on mystery...
# ...

# %%
df = df.loc[~df['likeCount'].isna()]

# %%
df
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# GLoeAJUcz38                 Press This Button To Win $100,000!
# nM89Wl03Q4g   I Survived 50 Hours In A Maximum Security Prison
# ...                                                        ...
# RCvnytndd9c                      Last To Leave VR Wins $20,000
# pV7UcYW1OwA                Computer vs Console My Perspective.
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
# 56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# 3iaDrpKdaIc                   I Ubered Random People In A Tank
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# ayXxwJJId_c  I cant believe I spent over $500000 on mystery...
# ...

# %% [markdown]
# **Casting Dtypes**

# %%
df.dtypes
# Out:
# title            object
# description      object
# publishTime      object
# viewCount         int64
# likeCount       float64
# commentCount    float64
# dtype: object

# %%
df['likeCount'] = df['likeCount'].astype('int')
# Out:
# <ipython-input-88-be88c379487a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['likeCount'] = df['likeCount'].astype('int')

# %%
df['viewCount'] = df['viewCount'].astype('int')
# Out:
# <ipython-input-89-fe86e236539f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['viewCount'] = df['viewCount'].astype('int')

# %%
df.dtypes
# Out:
# title            object
# description      object
# publishTime      object
# viewCount         int64
# likeCount         int64
# commentCount    float64
# dtype: object

# %%
df['publishTime'] = pd.to_datetime(df['publishTime'])
# Out:
# <ipython-input-91-0151a43537ee>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['publishTime'] = pd.to_datetime(df['publishTime'])

# %%
df['viewCount'].plot(kind='hist', bins=50, title='Distribution of View Count', 
                     figsize=(15,5))
# Out:
# <Axes: title={'center': 'Distribution of View Count'}, ylabel='Frequency'>

# %%
df.plot(kind='scatter', x= 'viewCount', y= 'likeCount')
# Out:
# <Axes: xlabel='viewCount', ylabel='likeCount'>

# %%
df.query('likeCount > 10000000')
# Out:
#                                                        title  \
# id
# 0e3GPea1Tyg                $456,000 Squid Game In Real Life!
# dBxOYE2j55U  Make This Video The Most Liked Video On Youtube
#
#                                                    description  \
# id
# 0e3GPea1Tyg  MAKE SURE YOU WATCH UNTIL GLASS BRIDGE IT'S IN...
# dBxOYE2j55U  WHAT IS UP LOGANG, MAKE SURE YOU LIKE THE VIDE...
#
#                           publishTime  viewCount  likeCount  commentCount
# id
# 0e3GPea1Tyg 2021-11-24 21:00:01+00:00  174984311   12129741      569635.0
# dBxOYE2j55U 2019-01-16 22:05:01+00:00   96461544   19036898      277069.0

# %%
df.plot(kind='scatter', x= 'publishTime', y= 'viewCount')
# Out:
# <Axes: xlabel='publishTime', ylabel='viewCount'>

# %%
df.to_csv('processedData.csv')
